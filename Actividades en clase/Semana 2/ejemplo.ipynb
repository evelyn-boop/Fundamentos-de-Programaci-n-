# %% [markdown]
# Ejercicios semana 2

# %%
edad= 19
if edad >=19:
    print("Eres mayor de edad")
else:
    print("Eres menor de edad")
# Out:
# Eres mayor de edad

# %%
calificacion =86
conducta = 10
if calificacion >=90:
    print("A")
    if conducta >=10:
        print("Tu conducta es excelente")
elif calificacion >=80:
    print("B")
elif calificacion >=70:
    print ("C")
elif calificacion >=60:
    print("D")
else:
    print("E")
# Out:
# B

# %% [markdown]
# Operadores lógicos

# %%
PL1 = not True
PL2 = False

print(PL1 or PL2)
# Out:
# False

# %%
edad = 55
tipo = "adulto_mayor"


es_mayor = edad >=18
print("es_mayor")
aplica_descuento = (edad >=60) and (tipo == "adulto_mayor")

print(aplica_descuento)
# Out:
# es_mayor
# False

# %%
edad = int (input("Ingresa tu edad"))

if (edad < 0 ):
    print("Aguanta, no hay edades menores a 0")
else:
    print("Ahora si vamos a trabajar con edades reales")
# Out:
# Aguanta, no hay edades menores a 0

# %%
precio=45 
if tipo == "adulto mayor":
    descuento = precio * 0.12   #5.40
elif tipo == "profesor" or tipo == "estudiante":
    descuento = precio * 0.10  #4.50
else:
    descuento = 0 
total = precio - descuento
print(f"Total a pagar:  $ (total:2f)") #Ej.adulto mayor
# Out:
# Total a pagar:  $ (total:2f)

# %% [markdown]
# TABLA

# %%
tabla = int(input("Qué tabla quieres que muestre"))

#for(int i = 1; i <10; i++)
print("\nFor")
for m in range (1,10):
    print(tabla, "x", m, "=", tabla * m)

    print("\nwhile")
    m=1
    while m <=10:
        print(f"{tabla} X {m}= {tabla * m}")
        m +=1
# Out:
# For
# 5 x 1 = 5
#
# while
# 5 X 1= 5
# 5 X 2= 10
# 5 X 3= 15
# 5 X 4= 20
# 5 X 5= 25
# 5 X 6= 30
# 5 X 7= 35
# 5 X 8= 40
# 5 X 9= 45
# 5 X 10= 50
# 5 x 2 = 10
#
# while
# 5 X 1= 5
# 5 X 2= 10
# 5 X 3= 15
# 5 X 4= 20
# 5 X 5= 25
# 5 X 6= 30
# 5 X 7= 35
# 5 X 8= 40
# 5 X 9= 45
# 5 X 10= 50
# 5 x 3 = 15
#
# while
# 5 X 1= 5
# 5 X 2= 10
# 5 X 3= 15
# 5 X 4= 20
# 5 X 5= 25
# 5 X 6= 30
# 5 X 7= 35
# 5 X 8= 40
# 5 X 9= 45
# 5 X 10= 50
# 5 x 4 = 20
#
# while
# 5 X 1= 5
# 5 X 2= 10
# 5 X 3= 15
# 5 X 4= 20
# 5 X 5= 25
# 5 X 6= 30
# 5 X 7= 35
# 5 X 8= 40
# 5 X 9= 45
# 5 X 10= 50
# 5 x 5 = 25
#
# while
# 5 X 1= 5
# 5 X 2= 10
# 5 X 3= 15
# 5 X 4= 20
# 5 X 5= 25
# 5 X 6= 30
# 5 X 7= 35
# 5 X 8= 40
# 5 X 9= 45
# 5 X 10= 50
# 5 x 6 = 30
#
# while
# 5 X 1= 5
# 5 X 2= 10
# 5 X 3= 15
# 5 X 4= 20
# 5 X 5= 25
# 5 X 6= 30
# 5 X 7= 35
# 5 X 8= 40
# 5 X 9= 45
# 5 X 10= 50
# 5 x 7 = 35
#
# while
# 5 X 1= 5
# 5 X 2= 10
# 5 X 3= 15
# 5 X 4= 20
# 5 X 5= 25
# 5 X 6= 30
# 5 X 7= 35
# 5 X 8= 40
# 5 X 9= 45
# ...

# %% [markdown]
# Ejercicios

# %% [markdown]
# Ejercicio 1

# %%
edad= int(input("Ingresa tu edad"))
if edad >=18:
    print("Eres mayor de edad")
else:
     print("Eres menor de edad")
# Out:
# Eres mayor de edad

# %% [markdown]
# Ejercicio 2

# %%
numero= int(input("Ingresa un numero entero"))
if(numero % 2 ==0):
    print("Es un numero par")
else:
    print("Es un numero impar")
# Out:
# Es un numero impar

# %% [markdown]
# Ejercicio 3

# %%
calificacion = float(input("Ingresa tu calificacion"))
if calificacion >= 6.0:
    print("Aprobaste")
else:
    print("Reprobaste")
# Out:
# Aprobaste

# %% [markdown]
# Ejercici0 4

# %%
edad=int(input("Ingresa tu edad:"))
if edad <3:
    print("Niño menos de 3 años")
elif edad < 13:
    print("Niño")
elif edad < 18:
    print("Adolescente")
elif edad < 60:
    print("Adulto")
else:
    print("Adulto mayor")

# %% [markdown]
# Ejercicio 5

# %%
precio_base=45

tipo=input("Ingrese el precio del boleto dependiendo si es adulto_mayor, profesor, estudiante u otro")
if tipo == "adulto_mayor":
    descuento= 0.12
elif tipo == "profesor" or tipo == "estudiante":
    descuento = 0.10
else:
    descuento = 0.00
    precio_final= precio_base * (1 - descuento)
    print(f"Precio final: $ {precio_final: .2f}")
# Out:
# Precio final: $  45.00

# %% [markdown]
# Ejercicio 6

# %%
edad= int(input("Ingresa tu edad : "))
credencial=input("¿Tienes credencial vigente? si/no):")
if edad >=18 and credencial == "si":
    print("Acceso permitido : ")
else:
    print("Acceso denegado : ")
# Out:
# Acceso permitido :

# %% [markdown]
# Ejercicio 7

# %%
num1 = int(input("Ingresa el primer número: "))
num2 = int(input("Ingresa el segundo número: "))

if num1 < 0 or num2 < 0:
    print("Hay un número negativo")
else:
    print("No hay números negativos")
# Out:
# Hay un número negativo

# %% [markdown]
# Ejercicio 8

# %%
numero = int(input("Ingresa un número entero: "))

if numero > 0:
    if numero % 2 == 0:
        print(f"El número {numero} es positivo y par")
    else:
        print(f"El número {numero} es positivo pero no es par")
else:
    print(f"El número {numero} no es positivo")
# Out:
# El número 10 es positivo y par

# %% [markdown]
# Ejercicio 9

# %%
respuesta = input("¿Deseas continuar? (si/no): ")

if not (respuesta == "si"):
    print("Proceso finalizado")
else:
    print("El proceso continúa")
# Out:
# El proceso continúa

# %% [markdown]
# Ejercicio 10

# %%
# Ejercicio 10
numero = int(input("Ingresa un número: "))

if numero % 2 == 0:
    print("El número es par")
else:
    print("El número es impar")

# %% [markdown]
# Ejercicio 11

# %%
# Ejercicio 11
nombre = input("Ingresa tu nombre: ")
edad = int(input("Ingresa tu edad: "))

print(f"Hola {nombre}, tienes {edad} años")

# %% [markdown]
# Ejercicio 12

# %%
# Ejercicio 12
a = int(input("Ingresa el primer número: "))
b = int(input("Ingresa el segundo número: "))

suma = a + b
print("La suma es:", suma)

# %% [markdown]
# Ejercicio 13

# %%
# Ejercicio 13
a = int(input("Ingresa el primer número: "))
b = int(input("Ingresa el segundo número: "))

if a > b:
    print(a, "es mayor")
else:
    print(b, "es mayor")

# %% [markdown]
# Ejercicio 14

# %%
# Ejercicio 14
numero = int(input("Ingresa un número: "))

if numero > 0:
    print("Positivo")
elif numero < 0:
    print("Negativo")
else:
    print("Cero")

# %% [markdown]
# Ejercicio 15

# %%
# Ejercicio 15
numero = int(input("Ingresa un número: "))

for i in range(1, 11):
    print(numero, "x", i, "=", numero * i)

# %% [markdown]
# Ejercicio 16

# %%
# Ejercicio 16
clave = ""
while clave != "secreto":
    clave = input("Escribe la contraseña: ")
print("Acceso concedido")

# %% [markdown]
# Ejercicio 17

# %%
suma_pares = 0
contador = 0
while contador < 5:
    numero = int(input(""))
    contador += 1
    if numero % 2 != 0:
        continue
    suma_pares += numero
print(f"La suma de los pares es: {suma_pares}")

# %% [markdown]
# Ejercicio 18

# %%
total = 0
while True:
    numero = int(input(""))
    total += numero
    if total >= 100:
        break
print(f"Total: {total}")

# %% [markdown]
# Ejercicio 19

# %%
# Error de sintaxis: falta la comilla de cierre en la cadena
# Código incorrecto: print("Hola
# Código corregido:
print("Hola")

# %% [markdown]
# Ejercicio 20

# %%
a = 8
b = 9
c = 10
# Código incorrecto: promedio = a + b + c / 3
promedio = (a + b + c) / 3
print(f"Error de lógica: falta agrupar la suma con paréntesis; promedio correcto = {promedio:.1f}")

# %% [markdown]
# Ejercicio 21

# %%
import pdb

x = 5
pdb.set_trace()
x = x + 3

# %% [markdown]
# Ejercicio 22

# %%
# n: ejecuta la siguiente línea
# c: continúa hasta el final
# p: imprime el valor de una expresión
# l: lista el código actual
# q: sale del depurador

# %% [markdown]
# Ejercicio 23

# %%
# edad = int(input("Edad: "))
# Al introducir "veinte":
# ValueError: invalid literal for int() with base 10: 'veinte'

# %% [markdown]
# Ejercicio 24

# %%
i = 1
while i <= 5:
    print(i)
    i = i + 1

# %% [markdown]
# Ejercicio 25

# %% [markdown]
# a = 10
# b = 0
# # division = a / b

# %% [markdown]
# Ejercicio 26

# %%
total = 0
i = 1
while i <= 4:
    total = total + i
    i = i + 1
print(f"Al terminar el ciclo: total = {total}, i = {i}")

# %% [markdown]
# Ejercicio 27

# %%
for numero in range(1, 6):
    print(numero)

# %% [markdown]
# Ejercicio 28

# %%
suma = 0
for i in range(1, 11):
    suma += i
print(f"La suma del 1 al 10 es: {suma}")

# %% [markdown]
# Ejercicio 29

# %%
numero = int(input("Ingresa un número: "))
for i in range(1, 11):
    print(f"{numero} x {i} = {numero * i}")

# %% [markdown]
# Ejercicio 30

# %%
suma_pares = 0
for i in range(1, 11):
    if i % 2 == 0:
        suma_pares += i
print(f"La suma de los pares del 1 al 10 es: {suma_pares}")

# %% [markdown]
# Ejercicio 31

# %%
filas = int(input("Ingresa el número de filas: "))
for i in range(1, filas + 1):
    for j in range(1, i + 1):
        print(j, end="")
    print()

# %% [markdown]
# Ejercicio 32

# %%
for numero in range(5, 0, -1):
    print(numero)

# %% [markdown]
# Ejercicio 33

# %%
numero = int(input("Ingresa un número entero positivo: "))
factorial = 1
for i in range(1, numero + 1):
    factorial *= i
print(f"El factorial de {numero} es: {factorial}")

# %% [markdown]
# Ejercicio 34

# %%
cantidad = int(input("Ingresa cuántas calificaciones se capturarán: "))
suma = 0
for i in range(cantidad):
    calificacion = float(input(""))
    suma += calificacion
promedio = suma / cantidad
print(f"El promedio es: {promedio:.1f}")

# %% [markdown]
# Ejercicio 35

# %%
n = int(input("Ingresa un número N: "))
for i in range(1, n + 1):
    print(i * i)
