# %% [markdown]
# calculadora interactiva en Python

# %% [markdown]
# ## 1. Descripción del reto
#
# Desarrollar una **calculadora interactiva en Python** que permita registrar el tiempo diario (en horas o fracciones de hora) que una persona dedica a distintas plataformas digitales: redes sociales, mensajería, servicios de streaming, videojuegos, entre otras. El programa debe capturar los datos, procesarlos y mostrar un resumen claro y ordenado de los resultados.
# Este reto integra el modelo **Entrada-Proceso-Salida** (Tema 1), la lógica algorítmica en **pseudocódigo y PSeInt** (Tema 2), el uso correcto de **variables, tipos de datos y operadores** (Tema 3) y las **entradas y salidas simples** con `input()`, `print()` y conversión de tipos (Tema 4).
# ## 2. Requerimientos técnicos obligatorios
# 1. **Nombre del usuario:** Solicitar el nombre del usuario mediante la función `input()`.
# 2. **Mínimo cinco plataformas:** Solicitar el tiempo diario dedicado a **al menos cinco** plataformas digitales diferentes (ej. redes sociales, mensajería, streaming, videojuegos, estudio en línea).
# 3. **Tiempos parciales:** Emplear la función `float()` para permitir el ingreso de tiempos parciales (ej. `1.5` horas).
# 4. **Tiempo total:** Calcular la suma del tiempo total diario invertido en actividades digitales.
# 5. **Porcentaje del día:** Calcular el porcentaje del día (24 horas) utilizado en actividades digitales mediante la fórmula:
#    `porcentaje = (tiempo_total / 24) * 100`
# 6. **Salida ordenada:** Mostrar en pantalla, de forma ordenada y formateada (f-strings), el **nombre del usuario**, el **tiempo total acumulado** y el **porcentaje calculado**.

# %%
# CALCULADORA DE TIEMPO DIGITAL  
  
# Colores para la consola  
MORADO = "\033[95m"  
AZUL = "\033[94m"  
CYAN = "\033[96m"  
VERDE = "\033[92m"   
ROJO = "\033[91m"  
BLANCO = "\033[97m"  
NEGRITA = "\033[1m"  
RESET = "\033[0m"  
  
# Título  
print(MORADO + NEGRITA + "CALCULADORA DE TIEMPO DIGITAL" + RESET)  
print()  
  
# Entrada de datos  
print(CYAN + "Ingresa las horas que pasas en cada plataforma:" + RESET)  
print()  

nombre = input(AZUL + "¿Cuál es tu nombre? " + RESET)
print()
  
redes = float(input(AZUL + "¿Cuántas horas pasas en redes sociales? " + RESET)) 
mensajeria = float(input(AZUL + "¿Cuántas horas pasas en mensajería? " + RESET))  
streaming = float(input(AZUL + "¿Cuántas horas pasas en servicios de streaming? " + RESET))  
videojuegos = float(input(AZUL + "¿Cuántas horas pasas jugando videojuegos? " + RESET))  
otras = float(input(AZUL + "¿Cuántas horas pasas en otras plataformas? " + RESET))  
  
# Proceso  
total = redes + mensajeria + streaming + videojuegos + otras  
  
promedio = total / 5

porcentaje = (total / 24) * 100
  
# Resultados  
print()  
print(MORADO + NEGRITA + "RESUMEN" + RESET)  
print()  

print(f"{AZUL}Usuario: {BLANCO}{nombre}{RESET}")
  
print(f"{AZUL}Redes sociales: {BLANCO}{redes} horas{RESET}")  
print(f"{CYAN}Mensajería: {BLANCO}{mensajeria} horas{RESET}")  
print(f"{VERDE}Streaming: {BLANCO}{streaming} horas{RESET}")  
print(f"{ROJO}Videojuegos: {BLANCO}{videojuegos} horas{RESET}")  
print(f"{AZUL}Otras plataformas: {BLANCO}{otras} horas{RESET}")  
  
print()  
  
print(f"{VERDE}{NEGRITA}Tiempo total: {total} horas{RESET}")  
  
print(f"{CYAN}{NEGRITA}Promedio por plataforma: {promedio} horas{RESET}")

print(f"{MORADO}{NEGRITA}Porcentaje del día: {porcentaje}%{RESET}")
# Out:
# CALCULADORA DE TIEMPO DIGITAL
#
# Ingresa las horas que pasas en cada plataforma:
#
#
#
# RESUMEN
#
# Usuario: Eve
# Redes sociales: 5.0 horas
# Mensajería: 2.2 horas
# Streaming: 3.0 horas
# Videojuegos: 4.52 horas
# Otras plataformas: 1.0 horas
#
# Tiempo total: 15.719999999999999 horas
# Promedio por plataforma: 3.1439999999999997 horas
# Porcentaje del día: 65.49999999999999%
